# %%
#Assignment 2

1.True and False
2.AND,OR and NOT
3.Truth table:
OR table
    + or + = True
    + or - = True
    - or + = True
    - or - = False

AND Table
    + or + = True
    + or - = False
    - or + = False
    - or - = False

4.
(5 > 4) and (3 == 5) = False
not (5 > 4) = False
(5 > 4) or (3 == 5) =  True
not ((5 > 4) or (3 == 5)) = False
(True and True) and (True == False) = False
(not False) or (not True) = True

5. <,>,>=,<=,!=,==

6. '=' is to assign a value to a variable and '==' is used to check the two given operands are equal or not

7."ham",
  "spam",
  "spam"

8.
spam = 6
if spam == 1:
    print("hello")
elif spam == 2:
    print("howdy")
else:
    print("greetings")

9.Kernel -> Restart -> Restart

10. Break : break is used to break the loop under our requirements
continue : continue is used to continuously follow the loop

11. range(10),range(0,10),range(0,10,1) - all remains same which gives the result excluding 10

12.
for i in range(10):
    print(i)

a=0
b=10
while a<b:
    print(a)
    a=a+1
13. bacon()
